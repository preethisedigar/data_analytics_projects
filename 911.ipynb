# %% [markdown]
# <a href="https://colab.research.google.com/github/preethisedigar/data_analytics_projects/blob/main/911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('911.csv')
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title         timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  10-12-2015 17:40        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  10-12-2015 17:40  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  10-12-2015 17:40         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  10-12-2015 17:40         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  10-12-2015 17:40   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# ...

# %%
df.shape
# Out:
# (99492, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df.columns
# Out:
# Index(['lat', 'lng', 'desc', 'zip', 'title', 'timeStamp', 'twp', 'addr', 'e'], dtype='object')

# %%
df['zip'].value_counts().head(5)
# Out:
# zip
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: count, dtype: int64

# %%
df['twp'].value_counts().head(5)
# Out:
# twp
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: count, dtype: int64

# %%
df['title'].unique()
print (len(df['title'].unique()))
# Out:
# 110

# %%
x=df['title'].iloc[0]

# %%
x.split(':')[0]
# Out:
# 'EMS'

# %%
df['Reason']=df['title'].apply(lambda title:title.split(':')[0])

# %%
df['Reason'].unique()
# Out:
# array(['EMS', 'Fire', 'Traffic'], dtype=object)

# %%
df['Reason'].value_counts()
# Out:
# Reason
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: count, dtype: int64

# %%
sns.countplot(x='Reason',data=df,palette='viridis')
# Out:
# /tmp/ipython-input-2424239774.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Reason',data=df,palette='viridis')
# <Axes: xlabel='Reason', ylabel='count'>

# %%
type(df['timeStamp'].iloc[0])
# Out:
# str

# %%
df['timeStamp']=pd.to_datetime(df['timeStamp'].iloc[0])

# %%
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
time=df['timeStamp'].iloc[0]
time.dayofweek
# Out:
# 0

# %%
time.hour
# Out:
# 17

# %%
df['hour']=df['timeStamp'].apply(lambda time:time.hour)
df['month']=df['timeStamp'].apply(lambda time:time.month)
df['day of week']=df['timeStamp'].apply(lambda time:time.dayofweek)

# %%
df.head(3)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-10-12 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-10-12 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-10-12 17:40:00         NORRISTOWN
#
#                          addr  e Reason  hour  month  day of week
# 0      REINDEER CT & DEAD END  1    EMS    17     10            0
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS    17     10            0
# 2                    HAWS AVE  1   Fire    17     10            0

# %%
dmap={0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'sun'}

# %%
df['day of week']=df['day of week'].map(dmap)

# %%
df['day of week'].unique()
# Out:
# array(['Mon'], dtype=object)

# %%
sns.countplot(x='day of week',hue='Reason',data=df)
# Out:
# <Axes: xlabel='day of week', ylabel='count'>

# %%
sns.countplot(x='month',data=df,hue='Reason')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2,borderaxespad=0.)

# %%
bymonth=df.groupby('month').count()
bymonth.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# month
# 10     99492  99492  99492  86637  99492      99492  99449  98973  99492
#
#        Reason   hour  day of week
# month
# 10      99492  99492        99492

# %%
bymonth['lat'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
sns.lmplot(x='month',y='twp',data=bymonth.reset_index())

# %%
bymonth.reset_index()
# Out:
#    month    lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# 0     10  99492  99492  99492  86637  99492      99492  99449  98973  99492
#
#    Reason   hour  day of week
# 0   99492  99492        99492

# %%
df['date']=df['timeStamp'].apply(lambda t:t.date())

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-10-12 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-10-12 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-10-12 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-10-12 17:40:00         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-10-12 17:40:00   LOWER POTTSGROVE
#
# ...

# %%
df.groupby("date").count().head()
# Out:
#               lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# date
# 2015-10-12  99492  99492  99492  86637  99492      99492  99449  98973  99492
#
#             Reason   hour  month  day of week
# date
# 2015-10-12   99492  99492  99492        99492

# %%
df.groupby('date').count()['lat']
# Out:
# date
# 2015-10-12    99492
# Name: lat, dtype: int64

# %%
df.groupby('date').count()['lat'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
plt.tight_layout()

# %%
df[df['Reason']=="Traffic"].groupby('date').count()['lat'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df[df['Reason']=='Fire'].groupby('date').count()['lat'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df[df['Reason']=="EMS"].groupby('date').count()['lat'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.groupby(by=['day of week','hour']).count()['Reason'].unstack()
# Out:
# hour            17
# day of week
# Mon          99492

# %%
dayhour=df.groupby(by=['day of week','hour']).count()['Reason'].unstack()

# %%
sns.heatmap(dayhour,cmap='viridis')
# Out:
# <Axes: xlabel='hour', ylabel='day of week'>

# %%
sns.clustermap(dayhour)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2848497588.py in <cell line: 0>()
# ----> 1 sns.clustermap(dayhour)
#
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1256                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1257
# -> 1258     return plotter.plot(metric=metric, method=method,
#    1259                         colorbar_kws=cbar_kws,
#    1260                         row_cluster=row_cluster, col_cluster=col_cluster,
#
# ...

# %%
daymonth=df.groupby(by=['month','day of week']).count()['Reason'].unstack()

# %%
daymonth.head()
# Out:
# day of week    Mon
# month
# 10           99492

# %%
plt.figure(figsize=(12,6))
sns.heatmap(daymonth,cmap='viridis')
# Out:
# <Axes: xlabel='day of week', ylabel='month'>

# %% [markdown]
# **Finance Data**

# %%
from pandas_datareader import data, wb

# %%
df=pd.read_pickle('all_banks')
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
df.shape
# Out:
# (2517, 30)

# %%
df.columns
# Out:
# MultiIndex([('BAC',   'Open'),
#             ('BAC',   'High'),
#             ('BAC',    'Low'),
#             ('BAC',  'Close'),
#             ('BAC', 'Volume'),
#             (  'C',   'Open'),
#             (  'C',   'High'),
#             (  'C',    'Low'),
#             (  'C',  'Close'),
#             (  'C', 'Volume'),
#             ( 'GS',   'Open'),
#             ( 'GS',   'High'),
#             ( 'GS',    'Low'),
#             ( 'GS',  'Close'),
#             ( 'GS', 'Volume'),
#             ('JPM',   'Open'),
#             ('JPM',   'High'),
#             ('JPM',    'Low'),
#             ('JPM',  'Close'),
#             ('JPM', 'Volume'),
#             ( 'MS',   'Open'),
#             ( 'MS',   'High'),
#             ( 'MS',    'Low'),
#             ( 'MS',  'Close'),
#             ( 'MS', 'Volume'),
#             ('WFC',   'Open'),
#             ('WFC',   'High'),
#             ('WFC',    'Low'),
#             ('WFC',  'Close'),
#             ('WFC', 'Volume')],
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (BAC, Open)    2517 non-null   float64
#  1   (BAC, High)    2517 non-null   float64
#  2   (BAC, Low)     2517 non-null   float64
#  3   (BAC, Close)   2517 non-null   float64
#  4   (BAC, Volume)  2517 non-null   int64
#  5   (C, Open)      2517 non-null   float64
#  6   (C, High)      2517 non-null   float64
#  7   (C, Low)       2517 non-null   float64
#  8   (C, Close)     2517 non-null   float64
#  9   (C, Volume)    2517 non-null   int64
#  10  (GS, Open)     2517 non-null   float64
#  11  (GS, High)     2517 non-null   float64
#  12  (GS, Low)      2517 non-null   float64
#  13  (GS, Close)    2517 non-null   float64
#  14  (GS, Volume)   2517 non-null   int64
#  15  (JPM, Open)    2517 non-null   float64
#  16  (JPM, High)    2517 non-null   float64
# ...

# %%
from datetime import datetime
start=datetime(2006,1,1)
end=datetime(2016,1,1)

# %%
#bank of america
BAC=df['BAC']
BAC=BAC.loc[start:end]
BAC.head()

#citigroup
C=df['C']
C=C.loc[start:end]
C.head()

#goldman
GS=df['GS']
GS=GS.loc[start:end]
GS.head()

#jpmorgan
JPM=df['JPM']
JPM=JPM.loc[start:end]
JPM.head()

#morgan stanley
MS=df['MS']
MS=MS.loc[start:end]
MS.head()

#well fargo
WFC=df['WFC']
WFC=WFC.loc[start:end]

# %%
BAC.head()
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000

# %%
C.head()
# Out:
# Stock Info   Open   High    Low  Close   Volume
# Date
# 2006-01-03  490.0  493.8  481.1  492.9  1537660
# 2006-01-04  488.6  491.0  483.5  483.8  1871020
# 2006-01-05  484.4  487.8  484.0  486.2  1143160
# 2006-01-06  488.8  489.0  482.0  486.2  1370250
# 2006-01-09  486.0  487.4  483.0  483.9  1680740

# %%
GS.head()
# Out:
# Stock Info    Open    High     Low   Close   Volume
# Date
# 2006-01-03  126.70  129.44  124.23  128.87  6188700
# 2006-01-04  127.35  128.91  126.38  127.09  4862000
# 2006-01-05  126.00  127.32  125.61  127.04  3717600
# 2006-01-06  127.29  129.25  127.29  128.84  4319600
# 2006-01-09  128.50  130.62  128.00  130.39  4723500

# %%
JPM.head()
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  39.83  40.36  39.30  40.19  12839400
# 2006-01-04  39.78  40.14  39.42  39.62  13491800
# 2006-01-05  39.61  39.81  39.50  39.74   8109400
# 2006-01-06  39.92  40.24  39.55  40.02   7966900
# 2006-01-09  39.88  40.72  39.88  40.67  16575200

# %%
MS.head()
# Out:
# Stock Info   Open   High    Low  Close   Volume
# Date
# 2006-01-03  57.17  58.49  56.74  58.31  5377000
# 2006-01-04  58.70  59.28  58.35  58.35  7977800
# 2006-01-05  58.55  58.59  58.02  58.51  5778000
# 2006-01-06  58.77  58.85  58.05  58.57  6889800
# 2006-01-09  58.63  59.29  58.62  59.19  4144500

# %%
WFC.head()
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  31.60  31.98  31.20  31.90  11016400
# 2006-01-04  31.80  31.82  31.36  31.53  10871000
# 2006-01-05  31.50  31.56  31.31  31.50  10158000
# 2006-01-06  31.58  31.78  31.38  31.68   8403800
# 2006-01-09  31.68  31.82  31.56  31.68   5619600

# %%
tickers=['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)
bank_stocks.head()
# Out:
#               BAC                                     C                       \
# Stock Info   Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04  47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05  46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06  46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09  46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
#                      ...     MS                                  WFC         \
# Stock Info   Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                 ...
# 2006-01-03  1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04  1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05  1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
bank_stocks.columns.names=['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.9

# %%
for tick in tickers:
  print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.9
# C 564.1
# GS 247.92
# JPM 70.08
# MS 89.3
# WFC 58.52

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
returns=pd.DataFrame()

# %%
for tick in tickers:
  returns[tick+' Return']=bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=50)
# Out:
# /tmp/ipython-input-3595771006.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=50)
# <Axes: xlabel='MS Return', ylabel='Density'>

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],color='red',bins=50)
# Out:
# /tmp/ipython-input-3154198916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],color='red',bins=50)
# <Axes: xlabel='C Return', ylabel='Density'>

# %%
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
  bank_stocks[tick]['Close'].plot(label=tick,figsize=(10,4))
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4290870540.py in <cell line: 0>()
# ----> 1 bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
#
# ...

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2008-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].loc['2008-01-01':'2008-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stocks.xs(key='Volume',axis=1,level='Stock Info').corr(),annot=True)

# %%
close_corr=bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="d7446da8-a5ca-4766-9a8a-d63b55c1be0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
BAC[['Open','High','Low','Close']].loc['2015-01-01':'2015-12-31'].iplot(kind='candle')
# Out:
# <div>                            <div id="99e6d01c-85cd-448f-8caa-77ec240b2b7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
MS['Close'].loc['2015-01-01':'2017-01-01'].ta_plot(study='sma',periods=[13,21,55])
# Out:
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1656426083.py in <cell line: 0>()
# ----> 1 MS['Close'].loc['2015-01-01':'2017-01-01'].ta_plot(study='sma',periods=[13,21,55])
#
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py in _ta_plot(self, study, periods, column, include, str, detail, theme, sharing, filename, asFigure, **iplot_kwargs)
#    1629
#    1630         inset=study in ('sma','boll','ema','atr','ptps')
# -> 1631 	figure=get_study(self,ta_func,iplot_kwargs,iplot_study_kwargs,include=include,
#    1632 					 column=column,str=str,inset=inset)
#    1633
#
# ...

# %%
BAC['Close'].loc['2015-01-01':'2017-01-01'].ta_plot(study='boll')
# Out:
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3571374829.py in <cell line: 0>()
# ----> 1 BAC['Close'].loc['2015-01-01':'2017-01-01'].ta_plot(study='boll')
#
# /usr/local/lib/python3.12/dist-packages/cufflinks/plotlytools.py in _ta_plot(self, study, periods, column, include, str, detail, theme, sharing, filename, asFigure, **iplot_kwargs)
#    1629
#    1630         inset=study in ('sma','boll','ema','atr','ptps')
# -> 1631 	figure=get_study(self,ta_func,iplot_kwargs,iplot_study_kwargs,include=include,
#    1632 					 column=column,str=str,inset=inset)
#    1633
#
# ...
