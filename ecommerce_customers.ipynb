# %% [markdown]
# <a href="https://colab.research.google.com/github/preethisedigar/data_analytics_projects/blob/main/ecommerce_customers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website.

# %%
import numpy as np,pandas as pd
import matplotlib.pyplot as plt,seaborn as sns

# %%
data=pd.read_csv('Ecommerce_Customers.csv')

# %%
data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
data.tail()
# Out:
#                             Email  \
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address         Avatar  \
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...            Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320  PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...       Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...           Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...    DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# ...

# %%
data.shape
# Out:
# (500, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data['Avatar'].value_counts()
# Out:
# Avatar
# SlateBlue               7
# Cyan                    7
# CadetBlue               7
# GreenYellow             7
# Teal                    7
#                        ..
# MediumPurple            1
# CornflowerBlue          1
# LightGoldenRodYellow    1
# PowderBlue              1
# LawnGreen               1
# Name: count, Length: 138, dtype: int64

# %%
data.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
#no missing values
#no inappropriate values
#'Email', 'Address', 'Avatar' are categorical data
#'Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent' are numerical data

# %%
#to find outliers in num col
# List of numerical columns
num_col= data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']]

# Create a boxplot for each of the numerical columns
plt.figure(figsize=(12, 6))
sns.boxplot(data=num_col)
plt.xticks(rotation=90)
plt.show()

# %%
Q1 = data['Yearly Amount Spent'].quantile(0.25)
Q3 = data['Yearly Amount Spent'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# Removing outliers
data = data[(data['Yearly Amount Spent'] >= Q1 - 1.5 * IQR) & (data['Yearly Amount Spent'] <= Q3 + 1.5 * IQR)]

# Boxplot to confirm outlier removal

plt.boxplot(data['Yearly Amount Spent'])
plt.show()
# Out:
# 104.27555053652014

# %%
#to find outliers in num col
# List of numerical columns
num_col= data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']]

# Create a boxplot for each of the numerical columns
plt.figure(figsize=(12, 6))
sns.boxplot(data=num_col)
plt.xticks(rotation=90)
plt.show()

# %%
correlation_matrix = data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Assuming num_col is your DataFrame with numerical columns
correlation = num_col.corr()
correlation
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.057372        -0.029428
# Time on App                     -0.057372     1.000000         0.081289
# Time on Website                 -0.029428     0.081289         1.000000
# Length of Membership             0.002717    -0.021071        -0.034549
# Yearly Amount Spent              0.312259     0.479242         0.009920
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.002717             0.312259
# Time on App                      -0.021071             0.479242
# Time on Website                  -0.034549             0.009920
# Length of Membership              1.000000             0.787866
# Yearly Amount Spent               0.787866             1.000000

# %% [markdown]
# length of membership and yearly amount spent has high correlation

# %%
sns.pairplot(data)
plt.show()

# %%
sns.lmplot(x = 'Length of Membership', y = 'Yearly Amount Spent',
          data=data, scatter_kws={'alpha':0.3})

# %% [markdown]
# assigning x and y

# %%
X = data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
y = data['Yearly Amount Spent']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
np.random.seed(0)
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size = 0.3,random_state = 100)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Apply the StandardScaler to the selected columns
scaled_data = scaler.fit_transform(data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']])

# Convert the scaled data back to a DataFrame with proper column names
scaled_data_df = pd.DataFrame(scaled_data, columns=['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent'])

# Print the first few rows of the scaled data
print(scaled_data_df.head())
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0             1.478644     0.623496         2.507776              0.579130
# 1            -1.154748    -0.954646         0.202749             -0.905682
# 2            -0.054024    -0.729266         0.044640              0.602076
# 3             1.282280     1.707302        -0.344054             -0.428243
# 4             0.283736     0.765917         0.470016              0.959797
#
#    Yearly Amount Spent
# 0             1.211584
# 1            -1.449164
# 2            -0.153187
# 3             1.128685
# 4             1.367291

# %%
from sklearn.feature_selection import RFE #RFE stands for Recursive Feature Elimination

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([25.37161016, 38.70612403,  0.43295967, 61.7628752 ])

# %%
rfe = RFE(model,n_features_to_select=4)             # running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Avg. Session Length', True, 1),
#  ('Time on App', True, 1),
#  ('Time on Website', True, 1),
#  ('Length of Membership', True, 1)]

# %% [markdown]
# so rfe says all the x train col are important

# %%
#residuals analysis
model.fit(X_train,y_train)
y_pred_train = model.predict(X_train)
res = y_pred_train - y_train

# %%
sns.histplot(res, kde=True)
plt.title("Histogram of Residuals")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)
# Out:
# Mean Absolute Error (MAE): 7.63424034025132
# Mean Squared Error (MSE): 95.43314318857624
# R-squared (R2): 0.9794768632557412

# %%
residuals=y_test_pred
residuals
# Out:
# array([429.39962971, 430.64314057, 530.05255538, 551.0109875 ,
#        481.63104998, 512.41443122, 452.47107092, 450.01193916,
#        574.75887803, 473.55289323, 553.03642022, 536.3663178 ,
#        399.218197  , 571.94848596, 507.74055908, 494.50541493,
#        476.87778029, 589.69621838, 575.74734441, 535.27626681,
#        507.03227813, 337.72782478, 507.18211148, 516.11711733,
#        540.37934129, 408.95479646, 502.19408974, 558.66903397,
#        543.04579066, 553.80332895, 426.24171177, 685.1654344 ,
#        487.12431564, 479.77022149, 684.78860445, 590.81125873,
#        671.56926245, 404.80777984, 564.13004811, 496.10837914,
#        530.54786736, 494.69048072, 530.58139781, 490.00360527,
#        505.51192131, 558.72603781, 551.99094583, 418.99343363,
#        616.75988484, 610.22389274, 484.29728946, 411.62255073,
#        481.51019479, 465.7861345 , 523.28295404, 497.88291733,
#        375.61459208, 433.40743917, 486.17996322, 450.45435689,
# ...

# %%
sns.displot(residuals,bins=40,kde=True)

# %%
import pylab
import scipy.stats as stats


stats.probplot(residuals, dist="norm", plot=pylab)
pylab.show()

# %%
X_train = sm.add_constant(X_train)

# Fit the model
model = sm.OLS(y_train, X_train)
results = model.fit()

# Summary of the model
print(results.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Yearly Amount Spent   R-squared:                       0.982
# Model:                             OLS   Adj. R-squared:                  0.982
# Method:                  Least Squares   F-statistic:                     4735.
# Date:                 Sat, 14 Dec 2024   Prob (F-statistic):          2.71e-295
# Time:                         13:26:14   Log-Likelihood:                -1277.6
# No. Observations:                  343   AIC:                             2565.
# Df Residuals:                      338   BIC:                             2584.
# Df Model:                            4
# Covariance Type:             nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -1039.8149     28.002    -37.133      0.000   -1094.896    -984.734
# ...

# %%
# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Get the coefficients
coefficients = model.coef_

# Output the coefficients for all predictors
print("Coefficients for the predictors:")
print(f"Time spent on app: {coefficients[1]}")
print(f"Time spent on website: {coefficients[2]}")
print(f"Membership length: {coefficients[3]}")
print(f"Session length: {coefficients[0]}")

# Conclusion: Focus on the most impactful predictor
if coefficients[0] > coefficients[1] and coefficients[0] > coefficients[2] and coefficients[0] > coefficients[3]:
    print("Conclusion: Focus more on improving the mobile app experience.")
elif coefficients[1] > coefficients[0] and coefficients[1] > coefficients[2] and coefficients[1] > coefficients[3]:
    print("Conclusion: Focus more on improving the website experience.")
elif coefficients[2] > coefficients[0] and coefficients[2] > coefficients[1] and coefficients[2] > coefficients[3]:
    print("Conclusion: Focus more on improving membership experience.")
else:
    print("Conclusion: Focus more on improving session length for better engagement.")
# Out:
# Coefficients for the predictors:
# Time spent on app: 38.67768655484715
# Time spent on website: 0.4126446758837794
# Membership length: 61.447300762595546
# Session length: 25.605791551670407
# Conclusion: Focus more on improving session length for better engagement.

# %%
X = data[['Time on App', 'Time on Website','Length of Membership']]
y = data['Yearly Amount Spent']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Get the coefficients
coefficients = model.coef_

# Output the coefficients for time_on_app, time_on_website, and membership_length
print("Coefficients for the predictors:")
print(f"Time spent on app: {coefficients[0]}")
print(f"Time spent on website: {coefficients[1]}")
print(f"Membership length: {coefficients[2]}")

# Conclusion: Focus on app
if coefficients[2] > coefficients[0] and coefficients[1] :
    print("Conclusion: 'Yearly Amount Spent' Increases ")
else:
    print("Conclusion:'Yearly Amount Spent' decreases.")
# Out:
# Coefficients for the predictors:
# Time spent on app: 37.26582868196154
# Time spent on website: -0.20900590721731938
# Membership length: 61.46536237032362
# Conclusion: 'Yearly Amount Spent' Increases

# %%
df = pd.DataFrame(data)

# Features (X) and target (y)
X = df[['Time on App', 'Time on Website']]
y = df['Yearly Amount Spent']

# Initialize and train the model
model = LinearRegression()
model.fit(X, y)

# Get the coefficients
coefficients = model.coef_

# Output the coefficients for time_on_app and time_on_website
print("Coefficients for the predictors:")
print(f"Time spent on app: {coefficients[0]}")
print(f"Time spent on website: {coefficients[1]}")

# Conclusion: Focus on the most impactful predictor
if coefficients[0] > coefficients[1]:
    print("Conclusion: Focus more on improving the mobile app experience.")
else:
    print("Conclusion: Focus more on improving the website experience.")
# Out:
# Coefficients for the predictors:
# Time spent on app: 36.163939199909215
# Time spent on website: -2.146975057175932
# Conclusion: Focus more on improving the mobile app experience.

# %% [markdown]
# CONSLUSION
# Interpreting the results of this analysis can be nuanced. According to the model, the most important factor influencing customer behavior is not the time spent on the app or website, but rather the length of their membership. However, between the two predictors—time spent on the app versus the website —the app shows a much stronger impact. In fact, the data suggests that the time spent on the  site has little to no correlation with customer spending.
#
#  The most influential features on the User Yearly Spent are the time spent on the mobile app and the length of membership.
#
#  Contrary to our expectations, the time on website has minimal effects, with results opposite to what we initially believed.

# %%
import pandas as pd
with open('Ecommerce Customers','r')as file:
      data=file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-e446016ae1b5> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 with open('Ecommerce Customers','r')as file:
#       3       data=file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ecommerce Customers'
